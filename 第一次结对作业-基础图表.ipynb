# %%
import pandas as pd
import numpy as np
from pandas import Series
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_excel('data.xls')

# %%
data1=data.loc[data['专业']=='计算机科学与技术（大数据）']
data1=((data1.T).dropna()).T
data1
# Out:
#    性别     年级             专业  \
# 1   女  2017级  计算机科学与技术（大数据）
# 2   女  2017级  计算机科学与技术（大数据）
# 6   男  2017级  计算机科学与技术（大数据）
# 7   男  2017级  计算机科学与技术（大数据）
# 8   男  2017级  计算机科学与技术（大数据）
# 9   男  2017级  计算机科学与技术（大数据）
# 10  男  2017级  计算机科学与技术（大数据）
# 11  男  2017级  计算机科学与技术（大数据）
# 12  男  2017级  计算机科学与技术（大数据）
# 13  男  2017级  计算机科学与技术（大数据）
# 14  男  2017级  计算机科学与技术（大数据）
# 15  男  2017级  计算机科学与技术（大数据）
# 16  男  2017级  计算机科学与技术（大数据）
# 17  男  2017级  计算机科学与技术（大数据）
# 19  男  2017级  计算机科学与技术（大数据）
# 20  男  2017级  计算机科学与技术（大数据）
# 21  男  2017级  计算机科学与技术（大数据）
# 22  男  2017级  计算机科学与技术（大数据）
# 24  男  2017级  计算机科学与技术（大数据）
# 25  男  2017级  计算机科学与技术（大数据）
# 26  男  2017级  计算机科学与技术（大数据）
# 28  女  2017级  计算机科学与技术（大数据）
# 30  男  2017级  计算机科学与技术（大数据）
# 38  男  2017级  计算机科学与技术（大数据）
# 39  男  2017级  计算机科学与技术（大数据）
# 40  女  2017级  计算机科学与技术（大数据）
# 41  男  2017级  计算机科学与技术（大数据）
# 43  男  2017级  计算机科学与技术（大数据）
# 48  男  2017级  计算机科学与技术（大数据）
# 49  男  2017级  计算机科学与技术（大数据）
# 50  男  2017级  计算机科学与技术（大数据）
# 51  男  2017级  计算机科学与技术（大数据）
# 52  女  2017级  计算机科学与技术（大数据）
# 56  男  2017级  计算机科学与技术（大数据）
# 58  男  2016级  计算机科学与技术（大数据）
# 61  男  2017级  计算机科学与技术（大数据）
# 62  男  2017级  计算机科学与技术（大数据）
# 63  女  2017级  计算机科学与技术（大数据）
# 64  男  2017级  计算机科学与技术（大数据）
# 66  男  2017级  计算机科学与技术（大数据）
# 67  女  2017级  计算机科学与技术（大数据）
#
#                                               大数据应用开发  \
# 1                    哔哩哔哩（B站）┋蓝墨云班课┋网易云班课┋至诚大数据慕课实验平台
# 2                          哔哩哔哩（B站）┋蓝墨云班课┋至诚大数据慕课实验平台
# 6                               哔哩哔哩（B站）┋腾讯会议┋QQ群在线授课
# 7                           哔哩哔哩（B站）┋蓝墨云班课┋腾讯会议┋QQ群直播
# 8                                            哔哩哔哩（B站）
# 9                                      哔哩哔哩（B站）┋蓝墨云班课
# 10        哔哩哔哩（B站）┋蓝墨云班课┋腾讯会议┋QQ群直播┋网易云班课┋至诚大数据慕课实验平台
# 11                                      哔哩哔哩（B站）┋腾讯会议
# 12  哔哩哔哩（B站）┋蓝墨云班课┋腾讯会议┋QQ群直播┋QQ群在线授课┋网易云班课┋至诚大数据慕...
# 13                  哔哩哔哩（B站）┋腾讯会议┋QQ群在线授课┋至诚大数据慕课实验平台
# 14                                哔哩哔哩（B站）┋蓝墨云班课┋腾讯会议
# 15            哔哩哔哩（B站）┋腾讯会议┋QQ群直播┋QQ群在线授课┋至诚大数据慕课实验平台
# 16                         哔哩哔哩（B站）┋蓝墨云班课┋至诚大数据慕课实验平台
# 17                                           哔哩哔哩（B站）
# 19                                           哔哩哔哩（B站）
# 20                                           哔哩哔哩（B站）
# 21                                              蓝墨云班课
# 22                                     哔哩哔哩（B站）┋蓝墨云班课
# 24                                           哔哩哔哩（B站）
# 25                                      哔哩哔哩（B站）┋腾讯会议
# 26      哔哩哔哩（B站）┋蓝墨云班课┋腾讯会议┋QQ群直播┋QQ群在线授课┋至诚大数据慕课实验平台
# 28                               哔哩哔哩（B站）┋至诚大数据慕课实验平台
# 30                                           哔哩哔哩（B站）
# 38                         哔哩哔哩（B站）┋蓝墨云班课┋至诚大数据慕课实验平台
# 39                                              蓝墨云班课
# 40                                           哔哩哔哩（B站）
# 41                         哔哩哔哩（B站）┋蓝墨云班课┋至诚大数据慕课实验平台
# 43                                           哔哩哔哩（B站）
# 48                    哔哩哔哩（B站）┋蓝墨云班课┋腾讯会议┋至诚大数据慕课实验平台
# 49                         哔哩哔哩（B站）┋蓝墨云班课┋至诚大数据慕课实验平台
# 50     哔哩哔哩（B站）┋蓝墨云班课┋QQ群直播┋QQ群在线授课┋网易云班课┋至诚大数据慕课实验平台
# 51                         哔哩哔哩（B站）┋蓝墨云班课┋至诚大数据慕课实验平台
# 52                               哔哩哔哩（B站）┋至诚大数据慕课实验平台
# 56            哔哩哔哩（B站）┋蓝墨云班课┋腾讯会议┋QQ群直播┋QQ群在线授课┋网易云班课
# 58                                           哔哩哔哩（B站）
# 61                    哔哩哔哩（B站）┋蓝墨云班课┋腾讯会议┋至诚大数据慕课实验平台
# 62                                           哔哩哔哩（B站）
# 63                                           哔哩哔哩（B站）
# 64                                哔哩哔哩（B站）┋蓝墨云班课┋腾讯会议
# 66                                              蓝墨云班课
# 67                                     哔哩哔哩（B站）┋蓝墨云班课
#
#                                                 高级数据库  \
# 1                                               蓝墨云班课
# 2                                               蓝墨云班课
# 6                                            哔哩哔哩（B站）
# 7                                         至诚大数据慕课实验平台
# 8                                               蓝墨云班课
# 9                                               蓝墨云班课
# 10                                              蓝墨云班课
# 11                                               腾讯会议
# 12                                        蓝墨云班课┋QQ群直播
# 13                                               腾讯会议
# 14                                哔哩哔哩（B站）┋蓝墨云班课┋腾讯会议
# 15            哔哩哔哩（B站）┋腾讯会议┋QQ群直播┋QQ群在线授课┋至诚大数据慕课实验平台
# 16                                        至诚大数据慕课实验平台
# 17                                           哔哩哔哩（B站）
# 19                                              蓝墨云班课
# 20                                  蓝墨云班课┋至诚大数据慕课实验平台
# 21                                              蓝墨云班课
# 22                                         蓝墨云班课┋腾讯会议
# 24                                         腾讯会议┋QQ群直播
# 25                                               腾讯会议
# 26                                         腾讯会议┋QQ群直播
# 28                                  蓝墨云班课┋至诚大数据慕课实验平台
# 30                                              蓝墨云班课
# 38                                              蓝墨云班课
# 39                                              蓝墨云班课
# 40                                              蓝墨云班课
# 41                                              蓝墨云班课
# 43                                        至诚大数据慕课实验平台
# 48                          哔哩哔哩（B站）┋蓝墨云班课┋腾讯会议┋QQ群直播
# 49                                  蓝墨云班课┋至诚大数据慕课实验平台
# 50                                        蓝墨云班课┋QQ群直播
# 51                                              蓝墨云班课
# 52                                           哔哩哔哩（B站）
# 56  哔哩哔哩（B站）┋蓝墨云班课┋腾讯会议┋QQ群直播┋QQ群在线授课┋网易云班课┋至诚大数据慕...
# 58                                           哔哩哔哩（B站）
# 61                                              蓝墨云班课
# 62                                           哔哩哔哩（B站）
# 63                                              蓝墨云班课
# 64                                           哔哩哔哩（B站）
# 66                                              蓝墨云班课
# 67                                              蓝墨云班课
#
#                                               数据挖掘与分析  \
# 1                                               蓝墨云班课
# 2                                               蓝墨云班课
# 6                                            哔哩哔哩（B站）
# 7                                                腾讯会议
# 8                                               蓝墨云班课
# 9                                               蓝墨云班课
# 10                                              蓝墨云班课
# 11                                              蓝墨云班课
# 12                                        蓝墨云班课┋QQ群直播
# 13                                               腾讯会议
# 14                                   蓝墨云班课┋腾讯会议┋QQ群直播
# 15            哔哩哔哩（B站）┋腾讯会议┋QQ群直播┋QQ群在线授课┋至诚大数据慕课实验平台
# 16                                        至诚大数据慕课实验平台
# 17                                           哔哩哔哩（B站）
# 19                                              蓝墨云班课
# 20                                  蓝墨云班课┋至诚大数据慕课实验平台
# 21                                              蓝墨云班课
# 22                                         蓝墨云班课┋腾讯会议
# 24                                              蓝墨云班课
# 25                                              蓝墨云班课
# 26                                                 其他
# 28                                              蓝墨云班课
# 30                          哔哩哔哩（B站）┋蓝墨云班课┋腾讯会议┋QQ群直播
# 38                                              蓝墨云班课
# 39                                              蓝墨云班课
# 40                                              蓝墨云班课
# 41                                              蓝墨云班课
# 43                                        至诚大数据慕课实验平台
# 48                          哔哩哔哩（B站）┋蓝墨云班课┋腾讯会议┋QQ群直播
# 49                                              蓝墨云班课
# 50                                        蓝墨云班课┋QQ群直播
# 51                                              蓝墨云班课
# 52                                        至诚大数据慕课实验平台
# 56  哔哩哔哩（B站）┋蓝墨云班课┋腾讯会议┋QQ群直播┋QQ群在线授课┋网易云班课┋至诚大数据慕...
# 58                                           哔哩哔哩（B站）
# 61                                              蓝墨云班课
# 62                                           哔哩哔哩（B站）
# 63                                              蓝墨云班课
# 64                                哔哩哔哩（B站）┋蓝墨云班课┋腾讯会议
# 66                                              蓝墨云班课
# 67                                              蓝墨云班课
#
#                                                  软件工程  \
# 1                                             QQ群在线授课
# 2                                                 (空)
# 6                                            哔哩哔哩（B站）
# 7                                               QQ群直播
# 8                                 哔哩哔哩（B站）┋腾讯会议┋QQ群直播
# 9                                 哔哩哔哩（B站）┋蓝墨云班课┋腾讯会议
# 10                                         腾讯会议┋QQ群直播
# 11                                               腾讯会议
# 12                                        蓝墨云班课┋QQ群直播
# 13                                              蓝墨云班课
# 14                                哔哩哔哩（B站）┋蓝墨云班课┋腾讯会议
# 15            哔哩哔哩（B站）┋腾讯会议┋QQ群直播┋QQ群在线授课┋至诚大数据慕课实验平台
# 16                                               腾讯会议
# 17                                           哔哩哔哩（B站）
# 19                                哔哩哔哩（B站）┋腾讯会议┋QQ群直播
# 20                                           哔哩哔哩（B站）
# 21                                              蓝墨云班课
# 22                                哔哩哔哩（B站）┋蓝墨云班课┋腾讯会议
# 24                                           哔哩哔哩（B站）
# 25                                               腾讯会议
# 26                                                 其他
# 28                                           哔哩哔哩（B站）
# 30                                      哔哩哔哩（B站）┋腾讯会议
# 38                                哔哩哔哩（B站）┋腾讯会议┋QQ群直播
# 39                                           哔哩哔哩（B站）
# 40                                               腾讯会议
# 41                                         蓝墨云班课┋腾讯会议
# 43                                               腾讯会议
# 48                          哔哩哔哩（B站）┋蓝墨云班课┋腾讯会议┋QQ群直播
# 49                       蓝墨云班课┋腾讯会议┋QQ群直播┋至诚大数据慕课实验平台
# 50                       哔哩哔哩（B站）┋蓝墨云班课┋QQ群直播┋QQ群在线授课
# 51                                     哔哩哔哩（B站）┋蓝墨云班课
# 52                                               腾讯会议
# 56  哔哩哔哩（B站）┋蓝墨云班课┋腾讯会议┋QQ群直播┋QQ群在线授课┋网易云班课┋至诚大数据慕...
# 58                                           哔哩哔哩（B站）
# 61                                         蓝墨云班课┋腾讯会议
# 62                                           哔哩哔哩（B站）
# 63                                           哔哩哔哩（B站）
# 64                                         腾讯会议┋QQ群直播
# 66                                              蓝墨云班课
# 67                               哔哩哔哩（B站）┋蓝墨云班课┋QQ群直播
#
#                                              云计算与数据中心 18、你更倾向于哪种上课方式？  \
# 1                                    腾讯会议┋至诚大数据慕课实验平台            线上直播
# 2                                    腾讯会议┋至诚大数据慕课实验平台            线上直播
# 6                                            哔哩哔哩（B站）            线上直播
# 7                                                腾讯会议            线上录播
# 8                                                腾讯会议            线下听课
# 9                                          蓝墨云班课┋腾讯会议            线上直播
# 10                                         腾讯会议┋QQ群直播            线上直播
# 11                                               腾讯会议            线上直播
# 12                             蓝墨云班课┋腾讯会议┋至诚大数据慕课实验平台            线上直播
# 13                                   腾讯会议┋至诚大数据慕课实验平台            线上直播
# 14                                哔哩哔哩（B站）┋蓝墨云班课┋腾讯会议            线下听课
# 15            哔哩哔哩（B站）┋腾讯会议┋QQ群直播┋QQ群在线授课┋至诚大数据慕课实验平台            线上录播
# 16                                               腾讯会议            线上录播
# 17                                           哔哩哔哩（B站）            线上直播
# 19                                               腾讯会议            线下听课
# 20                                               腾讯会议            线下听课
# 21                                              蓝墨云班课            线下听课
# 22                                   腾讯会议┋至诚大数据慕课实验平台            线下听课
# 24                                               腾讯会议            线下听课
# 25                                   腾讯会议┋至诚大数据慕课实验平台            线上直播
# 26                                                 其他            线下听课
# 28                                               腾讯会议            线下听课
# 30                             腾讯会议┋QQ群直播┋至诚大数据慕课实验平台            线下听课
# 38                                         腾讯会议┋QQ群直播            线上录播
# 39                                   腾讯会议┋至诚大数据慕课实验平台            线下听课
# 40                                               腾讯会议            线下听课
# 41                                   腾讯会议┋至诚大数据慕课实验平台            线上直播
# 43                                   腾讯会议┋至诚大数据慕课实验平台            线下听课
# 48                          哔哩哔哩（B站）┋蓝墨云班课┋腾讯会议┋网易云班课            线下听课
# 49                             腾讯会议┋QQ群直播┋至诚大数据慕课实验平台            线上直播
# 50                    蓝墨云班课┋QQ群直播┋QQ群在线授课┋至诚大数据慕课实验平台            线上直播
# 51                             蓝墨云班课┋腾讯会议┋至诚大数据慕课实验平台            线下听课
# 52                                               腾讯会议            线下听课
# 56  哔哩哔哩（B站）┋蓝墨云班课┋腾讯会议┋QQ群直播┋QQ群在线授课┋网易云班课┋至诚大数据慕...            线上直播
# 58                                           哔哩哔哩（B站）            线上直播
# 61                                   腾讯会议┋至诚大数据慕课实验平台            线上直播
# 62                                           哔哩哔哩（B站）            线上直播
# 63                                           哔哩哔哩（B站）            线下听课
# 64                                     哔哩哔哩（B站）┋蓝墨云班课            线上录播
# 66                                              蓝墨云班课            线下听课
# 67                                         腾讯会议┋QQ群直播            线上录播
#
#         观看设备  ...   课堂知识的吸收度 线下听课做笔记情况 线上听课做笔记情况  \
# 1   手机/平板┋电脑  ...    51%-75%     一直做笔记     适当做笔记
# 2   手机/平板┋电脑  ...    51%-75%     适当做笔记     适当做笔记
# 6         电脑  ...    51%-75%     适当做笔记     适当做笔记
# 7         电脑  ...    51%-75%     一直做笔记     适当做笔记
# 8         电脑  ...    51%-75%     适当做笔记      完全不做
# 9         电脑  ...      0-25%     适当做笔记      完全不做
# 10        电脑  ...    51%-75%     适当做笔记     适当做笔记
# 11  手机/平板┋电脑  ...   76%-100%     适当做笔记     适当做笔记
# 12  手机/平板┋电脑  ...   76%-100%      完全不做      完全不做
# 13        电脑  ...   76%-100%      完全不做      完全不做
# 14  手机/平板┋电脑  ...    51%-75%     一直做笔记     适当做笔记
# 15  手机/平板┋电脑  ...   76%-100%     适当做笔记     适当做笔记
# 16        电脑  ...    51%-75%     适当做笔记     适当做笔记
# 17        电脑  ...    51%-75%     适当做笔记     适当做笔记
# 19        电脑  ...    51%-75%     适当做笔记      完全不做
# 20        电脑  ...    51%-75%     适当做笔记     适当做笔记
# 21        电脑  ...    51%-75%     适当做笔记     适当做笔记
# 22     手机/平板  ...    26%-50%     适当做笔记     适当做笔记
# 24        电脑  ...    26%-50%     适当做笔记     适当做笔记
# 25  手机/平板┋电脑  ...    51%-75%     适当做笔记     适当做笔记
# 26        电脑  ...    51%-75%     适当做笔记      完全不做
# 28  手机/平板┋电脑  ...    26%-50%     一直做笔记     适当做笔记
# 30        电脑  ...    51%-75%     适当做笔记     一直做笔记
# 38        电脑  ...    51%-75%     适当做笔记     适当做笔记
# 39        电脑  ...      0-25%     一直做笔记      完全不做
# 40        电脑  ...    51%-75%     适当做笔记     适当做笔记
# 41  手机/平板┋电脑  ...   76%-100%     适当做笔记     适当做笔记
# 43        电脑  ...    51%-75%     适当做笔记     适当做笔记
# 48  手机/平板┋电脑  ...   76%-100%     适当做笔记     适当做笔记
# 49  手机/平板┋电脑  ...    51%-75%     适当做笔记     适当做笔记
# 50  手机/平板┋电脑  ...   76%-100%      完全不做      完全不做
# 51        电脑  ...   76%-100%     一直做笔记     适当做笔记
# 52     手机/平板  ...    26%-50%     一直做笔记      完全不做
# 56        电脑  ...    51%-75%     适当做笔记     适当做笔记
# 58     手机/平板  ...      0-25%     一直做笔记     一直做笔记
# 61  手机/平板┋电脑  ...   76%-100%     适当做笔记     适当做笔记
# 62     手机/平板  ...    26%-50%     适当做笔记     适当做笔记
# 63        电脑  ...    26%-50%     适当做笔记     适当做笔记
# 64        电脑  ...    51%-75%     适当做笔记     适当做笔记
# 66        电脑  ...    51%-75%     适当做笔记     适当做笔记
# 67        电脑  ...    51%-75%     适当做笔记     适当做笔记
#
#                                             线上授课优点  \
# 1   时间分配自由┋不受老师管理，想干什么干什么┋支持录屏，可以重复观看┋师生互动不会显得环境吵杂
# 2                               时间分配自由┋支持录屏，可以重复观看
# 6                               时间分配自由┋支持录屏，可以重复观看
# 7                      不受老师管理，想干什么干什么┋师生互动不会显得环境吵杂
# 8                               时间分配自由┋支持录屏，可以重复观看
# 9                               时间分配自由┋支持录屏，可以重复观看
# 10                      不受老师管理，想干什么干什么┋支持录屏，可以重复观看
# 11                                          其他〖舒服〗
# 12               时间分配自由┋不受老师管理，想干什么干什么┋支持录屏，可以重复观看
# 13                           时间分配自由┋不受老师管理，想干什么干什么
# 14               时间分配自由┋不受老师管理，想干什么干什么┋支持录屏，可以重复观看
# 15                              时间分配自由┋支持录屏，可以重复观看
# 16                              时间分配自由┋支持录屏，可以重复观看
# 17                                          时间分配自由
# 19                              时间分配自由┋支持录屏，可以重复观看
# 20                           时间分配自由┋不受老师管理，想干什么干什么
# 21                                     支持录屏，可以重复观看
# 22                      不受老师管理，想干什么干什么┋支持录屏，可以重复观看
# 24                                  不受老师管理，想干什么干什么
# 25                                          时间分配自由
# 26                                          时间分配自由
# 28                              时间分配自由┋支持录屏，可以重复观看
# 30                                  不受老师管理，想干什么干什么
# 38               时间分配自由┋不受老师管理，想干什么干什么┋支持录屏，可以重复观看
# 39               时间分配自由┋不受老师管理，想干什么干什么┋支持录屏，可以重复观看
# 40                              时间分配自由┋支持录屏，可以重复观看
# 41                              时间分配自由┋支持录屏，可以重复观看
# 43                              时间分配自由┋支持录屏，可以重复观看
# 48               时间分配自由┋不受老师管理，想干什么干什么┋支持录屏，可以重复观看
# 49                                     支持录屏，可以重复观看
# 50               时间分配自由┋不受老师管理，想干什么干什么┋支持录屏，可以重复观看
# 51                             时间分配自由┋师生互动不会显得环境吵杂
# 52                                          时间分配自由
# 56                              时间分配自由┋支持录屏，可以重复观看
# 58                                          时间分配自由
# 61                                          时间分配自由
# 62                                     支持录屏，可以重复观看
# 63               时间分配自由┋不受老师管理，想干什么干什么┋支持录屏，可以重复观看
# 64                                  不受老师管理，想干什么干什么
# 66                                          时间分配自由
# 67                 时间分配自由┋支持录屏，可以重复观看┋师生互动不会显得环境吵杂
#
#                                   线上授课缺点    效率        作业完成度  \
# 1                                注意力难以集中  传统授课  能完成，但是百度成分高
# 2                                 知识难以吸收  传统授课        能独立完成
# 6                         平台声音吵杂┋注意力难以集中  线上授课        能独立完成
# 7                          平台声音吵杂┋平台太过卡顿  传统授课        能独立完成
# 8                        注意力难以集中┋周边环境影响大  传统授课        能独立完成
# 9                         平台太过卡顿┋注意力难以集中  传统授课  能完成，但是百度成分高
# 10                        注意力难以集中┋知识难以吸收  传统授课  能完成，但是百度成分高
# 11                                其他〖没有〗  线上授课        能独立完成
# 12                         平台声音吵杂┋平台太过卡顿  线上授课  能完成，但是百度成分高
# 13                 平台声音吵杂┋平台太过卡顿┋注意力难以集中  线上授课        能独立完成
# 14                        注意力难以集中┋知识难以吸收  传统授课        能独立完成
# 15                               注意力难以集中  线上授课        能独立完成
# 16                 平台声音吵杂┋注意力难以集中┋知识难以吸收  传统授课  能完成，但是百度成分高
# 17  平台声音吵杂┋平台太过卡顿┋注意力难以集中┋知识难以吸收┋周边环境影响大  线上授课        能独立完成
# 19                       注意力难以集中┋周边环境影响大  传统授课        能独立完成
# 20                        注意力难以集中┋知识难以吸收  传统授课  能完成，但是百度成分高
# 21                                平台太过卡顿  传统授课        能独立完成
# 22                平台太过卡顿┋注意力难以集中┋周边环境影响大  传统授课  能完成，但是百度成分高
# 24                         平台声音吵杂┋平台太过卡顿  传统授课  能完成，但是百度成分高
# 25                                 其他〖无〗  线上授课        能独立完成
# 26                                平台声音吵杂  传统授课  能完成，但是百度成分高
# 28                        注意力难以集中┋知识难以吸收  传统授课  能完成，但是百度成分高
# 30  平台声音吵杂┋平台太过卡顿┋注意力难以集中┋知识难以吸收┋周边环境影响大  传统授课        能独立完成
# 38                 平台声音吵杂┋平台太过卡顿┋注意力难以集中  传统授课        能独立完成
# 39          平台声音吵杂┋平台太过卡顿┋注意力难以集中┋知识难以吸收  传统授课        能独立完成
# 40                        平台太过卡顿┋周边环境影响大  传统授课        能独立完成
# 41          平台声音吵杂┋平台太过卡顿┋注意力难以集中┋知识难以吸收  传统授课        能独立完成
# 43                        平台太过卡顿┋注意力难以集中  传统授课        能独立完成
# 48  平台声音吵杂┋平台太过卡顿┋注意力难以集中┋知识难以吸收┋周边环境影响大  线上授课        能独立完成
# 49                        平台太过卡顿┋注意力难以集中  传统授课  能完成，但是百度成分高
# 50                         平台声音吵杂┋平台太过卡顿  线上授课  能完成，但是百度成分高
# 51         平台声音吵杂┋注意力难以集中┋知识难以吸收┋周边环境影响大  传统授课        能独立完成
# 52                        知识难以吸收┋周边环境影响大  传统授课        能独立完成
# 56                         平台声音吵杂┋平台太过卡顿  线上授课        能独立完成
# 58                                平台声音吵杂  线上授课        能独立完成
# 61                                其他〖没有〗  线上授课        能独立完成
# 62                                平台太过卡顿  线上授课        能独立完成
# 63                 平台声音吵杂┋平台太过卡顿┋周边环境影响大  传统授课  能完成，但是百度成分高
# 64                 平台太过卡顿┋注意力难以集中┋知识难以吸收  传统授课        能独立完成
# 66                                平台太过卡顿  传统授课        能独立完成
# 67                         平台声音吵杂┋平台太过卡顿  传统授课        能独立完成
#
#    28、你在听课时会不会做其他课外事情？ 29、你愿意线上听课还是愿意线下听课？ 网课满意度
# 1                    会                线下听课    满意
# 2                    会                线下听课    一般
# 6                    会                线上听课    满意
# 7                   不会                线下听课  很不满意
# 8                    会                线下听课    一般
# 9                    会                线上听课   很满意
# 10                   会                线上听课    满意
# 11                  不会                线上听课   很满意
# 12                   会                线上听课   很满意
# 13                   会                线下听课    满意
# 14                  不会                线下听课    一般
# 15                   会                线上听课   很满意
# 16                   会                线下听课    一般
# 17                   会                线上听课   很满意
# 19                   会                线下听课    一般
# 20                   会                线下听课    一般
# 21                   会                线下听课    一般
# 22                   会                线下听课    满意
# 24                   会                线下听课    满意
# 25                  不会                线上听课   很满意
# 26                  不会                线下听课   不满意
# 28                   会                线下听课    一般
# 30                   会                线下听课   不满意
# 38                   会                线下听课    一般
# 39                   会                线下听课    一般
# 40                  不会                线下听课    一般
# 41                   会                线下听课    一般
# 43                   会                线下听课    满意
# 48                   会                线上听课    一般
# 49                  不会                线下听课    满意
# 50                   会                线上听课   很满意
# 51                  不会                线下听课    满意
# 52                   会                线下听课    一般
# 56                   会                线上听课    一般
# 58                   会                线上听课   很满意
# 61                  不会                线上听课   很满意
# 62                   会                线上听课    一般
# 63                   会                线下听课  很不满意
# 64                   会                线下听课    一般
# 66                   会                线上听课    满意
# 67                   会                线上听课    满意
#
# [41 rows x 21 columns]

# %%
data2=data.loc[data['专业']=='计算机科学与技术（网络）']
data2=((data2.T).dropna()).T
data2
# Out:
#    性别     年级            专业          云计算与数据中心       入侵检测与安全扫描技术  \
# 3   女  2017级  计算机科学与技术（网络）              腾讯会议              腾讯会议
# 5   男  2017级  计算机科学与技术（网络）  腾讯会议┋至诚大数据慕课实验平台              腾讯会议
# 36  男  2017级  计算机科学与技术（网络）              腾讯会议              腾讯会议
# 42  男  2017级  计算机科学与技术（网络）  腾讯会议┋至诚大数据慕课实验平台  腾讯会议┋至诚大数据慕课实验平台
# 44  女  2017级  计算机科学与技术（网络）              腾讯会议              腾讯会议
# 45  男  2017级  计算机科学与技术（网络）              腾讯会议              腾讯会议
# 46  女  2017级  计算机科学与技术（网络）  腾讯会议┋至诚大数据慕课实验平台              腾讯会议
# 47  女  2017级  计算机科学与技术（网络）        腾讯会议┋QQ群直播              腾讯会议
# 53  男  2017级  计算机科学与技术（网络）        腾讯会议┋QQ群直播              腾讯会议
# 54  男  2017级  计算机科学与技术（网络）              腾讯会议              腾讯会议
# 55  男  2017级  计算机科学与技术（网络）        腾讯会议┋QQ群直播              腾讯会议
# 57  男  2017级  计算机科学与技术（网络）  腾讯会议┋至诚大数据慕课实验平台              腾讯会议
# 59  女  2017级  计算机科学与技术（网络）      腾讯会议┋QQ群在线授课              腾讯会议
# 60  男  2017级  计算机科学与技术（网络）              腾讯会议              腾讯会议
# 65  男  2017级  计算机科学与技术（网络）              腾讯会议              腾讯会议
# 69  男  2017级  计算机科学与技术（网络）              腾讯会议              腾讯会议
#
#    18、你更倾向于哪种上课方式？      观看设备 听课专注力  课堂知识的吸收度 线下听课做笔记情况 线上听课做笔记情况  \
# 3             线下听课        电脑  偶尔走神   51%-75%     一直做笔记     适当做笔记
# 5             线下听课     手机/平板  偶尔走神   26%-50%      完全不做      完全不做
# 36            线下听课  手机/平板┋电脑  认真专注   26%-50%     适当做笔记     适当做笔记
# 42            线下听课     手机/平板  偶尔走神   26%-50%     适当做笔记      完全不做
# 44            线下听课  手机/平板┋电脑  偶尔走神   26%-50%     适当做笔记     适当做笔记
# 45            线上直播        电脑  偶尔走神   51%-75%     适当做笔记     适当做笔记
# 46            线上录播        电脑  偶尔走神  76%-100%     适当做笔记     适当做笔记
# 47            线上录播     手机/平板  偶尔走神   51%-75%     适当做笔记      完全不做
# 53            线下听课     手机/平板  偶尔走神   51%-75%      完全不做      完全不做
# 54            线上直播        电脑  偶尔走神   51%-75%     适当做笔记     适当做笔记
# 55            线上直播        电脑  偶尔走神   51%-75%     适当做笔记     适当做笔记
# 57            线下听课     手机/平板  偶尔走神   51%-75%     适当做笔记     适当做笔记
# 59            线下听课        电脑  偶尔走神   51%-75%     适当做笔记      完全不做
# 60            线下听课        电脑  偶尔走神   51%-75%      完全不做      完全不做
# 65            线下听课     手机/平板  偶尔走神   51%-75%     适当做笔记      完全不做
# 69            线下听课        电脑  偶尔走神   51%-75%     适当做笔记      完全不做
#
#                                             线上授课优点  \
# 3                              时间分配自由┋师生互动不会显得环境吵杂
# 5   时间分配自由┋不受老师管理，想干什么干什么┋支持录屏，可以重复观看┋师生互动不会显得环境吵杂
# 36                                     支持录屏，可以重复观看
# 42  时间分配自由┋不受老师管理，想干什么干什么┋支持录屏，可以重复观看┋师生互动不会显得环境吵杂
# 44                              时间分配自由┋支持录屏，可以重复观看
# 45                                     支持录屏，可以重复观看
# 46                              时间分配自由┋支持录屏，可以重复观看
# 47                                     支持录屏，可以重复观看
# 53                              时间分配自由┋支持录屏，可以重复观看
# 54                              时间分配自由┋支持录屏，可以重复观看
# 55                 时间分配自由┋支持录屏，可以重复观看┋师生互动不会显得环境吵杂
# 57                                     支持录屏，可以重复观看
# 59                           时间分配自由┋不受老师管理，想干什么干什么
# 60                                    师生互动不会显得环境吵杂
# 65                                     支持录屏，可以重复观看
# 69                              时间分配自由┋支持录屏，可以重复观看
#
#                                   线上授课缺点    效率        作业完成度  \
# 3                         平台太过卡顿┋注意力难以集中  传统授课        能独立完成
# 5          平台声音吵杂┋注意力难以集中┋知识难以吸收┋周边环境影响大  传统授课  能完成，但是百度成分高
# 36                        注意力难以集中┋知识难以吸收  传统授课        能独立完成
# 42         平台声音吵杂┋平台太过卡顿┋注意力难以集中┋周边环境影响大  传统授课  能完成，但是百度成分高
# 44  平台声音吵杂┋平台太过卡顿┋注意力难以集中┋知识难以吸收┋周边环境影响大  传统授课  能完成，但是百度成分高
# 45                               注意力难以集中  传统授课        能独立完成
# 46                         平台声音吵杂┋平台太过卡顿  传统授课  能完成，但是百度成分高
# 47                         平台声音吵杂┋平台太过卡顿  传统授课  能完成，但是百度成分高
# 53                               注意力难以集中  传统授课  能完成，但是百度成分高
# 54                                平台声音吵杂  线上授课        能独立完成
# 55                               周边环境影响大  线上授课        能独立完成
# 57                       注意力难以集中┋周边环境影响大  传统授课  能完成，但是百度成分高
# 59          平台声音吵杂┋平台太过卡顿┋注意力难以集中┋知识难以吸收  传统授课  能完成，但是百度成分高
# 60                                知识难以吸收  传统授课         顺便做做
# 65                注意力难以集中┋知识难以吸收┋周边环境影响大  传统授课  能完成，但是百度成分高
# 69                                平台太过卡顿  线上授课        能独立完成
#
#    28、你在听课时会不会做其他课外事情？ 29、你愿意线上听课还是愿意线下听课？ 网课满意度
# 3                    会                线下听课    满意
# 5                    会                线下听课    一般
# 36                   会                线上听课    一般
# 42                   会                线下听课    一般
# 44                   会                线下听课    一般
# 45                   会                线下听课    一般
# 46                  不会                线上听课    一般
# 47                   会                线上听课    满意
# 53                   会                线下听课    一般
# 54                  不会                线上听课    一般
# 55                   会                线上听课    满意
# 57                   会                线下听课    满意
# 59                   会                线下听课    一般
# 60                   会                线下听课    一般
# 65                   会                线下听课    一般
# 69                   会                线上听课    满意

# %%
data3=data.loc[data['专业']=='软件工程']
data3=((data3.T).dropna()).T
data3
# Out:
#    性别     年级    专业   深度学习入门实践 前端框架应用 人机交互技术 数据库应用开发 18、你更倾向于哪种上课方式？      观看设备  \
# 29  女  2017级  软件工程   哔哩哔哩（B站）   腾讯会议   腾讯会议      其他            线下听课        电脑
# 32  男  2017级  软件工程       腾讯会议     其他   腾讯会议    斗鱼直播            线上直播        电脑
# 33  女  2017级  软件工程  腾讯会议┋斗鱼直播   腾讯会议   腾讯会议    腾讯会议            线上直播  手机/平板┋电脑
# 35  男  2017级  软件工程  腾讯会议┋斗鱼直播    (空)   腾讯会议    腾讯会议            线下听课        电脑
# 37  男  2017级  软件工程       腾讯会议   腾讯会议   腾讯会议    腾讯会议            线上直播        电脑
#
#    听课专注力  课堂知识的吸收度 线下听课做笔记情况 线上听课做笔记情况                      线上授课优点  \
# 29  偶尔走神     0-25%     适当做笔记     适当做笔记  不受老师管理，想干什么干什么┋支持录屏，可以重复观看
# 32  认真专注   51%-75%      完全不做     适当做笔记    支持录屏，可以重复观看┋师生互动不会显得环境吵杂
# 33  认真专注  76%-100%     适当做笔记     适当做笔记          时间分配自由┋支持录屏，可以重复观看
# 35  偶尔走神   26%-50%     适当做笔记      完全不做          时间分配自由┋支持录屏，可以重复观看
# 37  偶尔走神   51%-75%     适当做笔记      完全不做    支持录屏，可以重复观看┋师生互动不会显得环境吵杂
#
#                                   线上授课缺点    效率        作业完成度  \
# 29                               周边环境影响大  传统授课  能完成，但是百度成分高
# 32                                    其他  线上授课        能独立完成
# 33                               周边环境影响大  线上授课        能独立完成
# 35  平台声音吵杂┋平台太过卡顿┋注意力难以集中┋知识难以吸收┋周边环境影响大  传统授课  能完成，但是百度成分高
# 37                       注意力难以集中┋周边环境影响大  传统授课        能独立完成
#
#    28、你在听课时会不会做其他课外事情？ 29、你愿意线上听课还是愿意线下听课？ 网课满意度
# 29                  不会                线下听课    一般
# 32                  不会                线上听课    满意
# 33                  不会                线上听课   很满意
# 35                  不会                线下听课    一般
# 37                   会                线下听课    一般

# %%
data4=data.loc[data['专业']=='数字媒体技术']
data4=((data4.T).dropna()).T
data4
# Out:
#    性别     年级      专业         计算机操作系统 影视特效与非线性编辑实践 三维动画设计与实现  游戏设计与开发  \
# 27  女  2017级  数字媒体技术           网易云班课      QQ群在线授课   QQ群在线授课  QQ群在线授课
# 31  女  2017级  数字媒体技术           蓝墨云班课        蓝墨云班课     QQ群直播    QQ群直播
# 68  女  2017级  数字媒体技术  哔哩哔哩（B站）┋网易云班课     网易云班课┋其他     QQ群直播    QQ群直播
#
#    18、你更倾向于哪种上课方式？      观看设备 听课专注力  课堂知识的吸收度 线下听课做笔记情况 线上听课做笔记情况  \
# 27            线上直播  手机/平板┋电脑  认真专注  76%-100%     适当做笔记     适当做笔记
# 31            线上直播        电脑  偶尔走神   26%-50%     适当做笔记     适当做笔记
# 68            线下听课  手机/平板┋电脑  根本没听   26%-50%     适当做笔记      完全不做
#
#                                线上授课优点                  线上授课缺点    效率  作业完成度  \
# 27    时间分配自由┋支持录屏，可以重复观看┋师生互动不会显得环境吵杂                      其他  传统授课  能独立完成
# 31                 时间分配自由┋支持录屏，可以重复观看                  平台声音吵杂  线上授课  能独立完成
# 68  时间分配自由┋不受老师管理，想干什么干什么┋支持录屏，可以重复观看  注意力难以集中┋知识难以吸收┋周边环境影响大  传统授课  能独立完成
#
#    28、你在听课时会不会做其他课外事情？ 29、你愿意线上听课还是愿意线下听课？ 网课满意度
# 27                  不会                线上听课   很满意
# 31                   会                线上听课    一般
# 68                   会                线下听课    一般

# %%
data5=data.loc[data['专业']=='计算机金融实验班']
data5=((data5.T).dropna()).T
data5
# Out:
#    性别     年级        专业               高级数据库  \
# 4   女  2017级  计算机金融实验班            哔哩哔哩（B站）
# 18  男  2017级  计算机金融实验班             QQ群在线授课
# 23  女  2017级  计算机金融实验班               蓝墨云班课
# 34  男  2017级  计算机金融实验班  蓝墨云班课┋腾讯会议┋QQ群在线授课
#
#                                      数据挖掘与分析                            软件工程  \
# 4                                       斗鱼直播                              其他
# 18                                      腾讯会议                            腾讯会议
# 23                                     蓝墨云班课                             (空)
# 34  哔哩哔哩（B站）┋蓝墨云班课┋QQ群直播┋QQ群在线授课┋至诚大数据慕课实验平台  哔哩哔哩（B站）┋腾讯会议┋QQ群直播┋QQ群在线授课┋其他
#
#                云计算与数据中心 18、你更倾向于哪种上课方式？      观看设备 听课专注力 课堂知识的吸收度 线下听课做笔记情况  \
# 4                    其他            线上直播     手机/平板  根本没听    0-25%      完全不做
# 18              QQ群在线授课            线上直播     手机/平板  偶尔走神  51%-75%      完全不做
# 23    QQ群直播┋至诚大数据慕课实验平台            线上录播        电脑  偶尔走神  51%-75%     适当做笔记
# 34  蓝墨云班课┋QQ群直播┋QQ群在线授课            线上录播  手机/平板┋电脑  偶尔走神  51%-75%     适当做笔记
#
#    线上听课做笔记情况                                          线上授课优点  \
# 4       完全不做                                          时间分配自由
# 18     适当做笔记  时间分配自由┋不受老师管理，想干什么干什么┋支持录屏，可以重复观看┋师生互动不会显得环境吵杂
# 23     适当做笔记                              时间分配自由┋支持录屏，可以重复观看
# 34     适当做笔记                      不受老师管理，想干什么干什么┋支持录屏，可以重复观看
#
#                     线上授课缺点    效率        作业完成度 28、你在听课时会不会做其他课外事情？  \
# 4                   平台声音吵杂  传统授课         顺便做做                   会
# 18          平台太过卡顿┋周边环境影响大  传统授课  能完成，但是百度成分高                   会
# 23                 注意力难以集中  线上授课  能完成，但是百度成分高                   会
# 34  平台太过卡顿┋注意力难以集中┋周边环境影响大  传统授课         顺便做做                   会
#
#    29、你愿意线上听课还是愿意线下听课？ 网课满意度
# 4                 线下听课  很不满意
# 18                线下听课    一般
# 23                线上听课    一般
# 34                线下听课   不满意

# %% [markdown]
# ## 上课方式

# %%
data1LikeCount=data1['18、你更倾向于哪种上课方式？'].value_counts(ascending=False)
data2LikeCount=data2['18、你更倾向于哪种上课方式？'].value_counts(ascending=False)
data3LikeCount=data3['18、你更倾向于哪种上课方式？'].value_counts(ascending=False)
data4LikeCount=data4['18、你更倾向于哪种上课方式？'].value_counts(ascending=False)
data5LikeCount=data5['18、你更倾向于哪种上课方式？'].value_counts(ascending=False)
dataLikeCount=data['18、你更倾向于哪种上课方式？'].value_counts(ascending=False)
data3LikeCount=data3LikeCount.append(Series({'线上录播':0}))
data4LikeCount=data4LikeCount.append(Series({'线上录播':0}))
data5LikeCount=data5LikeCount.append(Series({'线下听课':0}))

# %%
plt.rcParams['font.sans-serif'] = ['simhei']
plt.rcParams['axes.unicode_minus'] = False
bar_width=0.15
labels1 = list(data1LikeCount.index)
plt.ylabel('数量(人)')
x=np.arange(len(labels1))
like1=plt.bar(x-2*bar_width,data1LikeCount,bar_width,color='red',label='计科大数据')
like2=plt.bar(x-bar_width,data2LikeCount,bar_width,color='orange',label='计科网络')
like3=plt.bar(x,data3LikeCount,bar_width,color='#E47833',label='软工')
like4=plt.bar(x+bar_width,data4LikeCount,bar_width,color='brown',label='数媒')
like5=plt.bar(x+2*bar_width,data5LikeCount,bar_width,color='#D89370',label='金融实验')
plt.xticks(x,labels1)
plt.title('不同专业倾向的上课方式',size=18)
plt.yticks(range(0,25,5))
plt.legend()
plt.show()

# %%
labels = list(dataLikeCount.index)
x=np.arange(len(labels))
bar_width=0.5
plt.bar(x,dataLikeCount,bar_width)
plt.title('学生倾向的上课方式',size=18)
plt.xticks(x,labels)
plt.yticks(range(0,40,5))
plt.show()

# %% [markdown]
# ## 观看设备

# %%
def c(data):
    y = [x for x in data['观看设备'].str.split('┋')]
    tel = 0
    comp = 0
    for item in y:
        for select in item:
            if select[0]=='手':
                tel = tel+1
            else:
                comp = comp + 1
    a=[]
    a.append(tel)
    a.append(comp)
    return a

# %%
plt.figure(figsize=(4,4))
watch_labels= ['手机/平板','电脑']
count=69
share =[(c(data))[0]/count,(c(data))[1]/count]
explode = [0.04, 0.04]
plt.pie(share, explode = explode,
        labels = watch_labels, autopct = '%3.2f%%',
        startangle = 60, shadow = False,
        colors = ['lightgreen', 'lightskyblue'])
plt.title('观看设备倾向',size=18)
plt.axis('equal')
plt.show()

# %% [markdown]
# ## 听课专注力

# %%
data1Att=data1['听课专注力'].value_counts(ascending=False)
data2Att=data2['听课专注力'].value_counts(ascending=False)
data3Att=data3['听课专注力'].value_counts(ascending=False)
data4Att=data4['听课专注力'].value_counts(ascending=False)
data5Att=data5['听课专注力'].value_counts(ascending=False)
dataAtt=data['听课专注力'].value_counts(ascending=False)
data2Att=data2Att.append(Series({'根本没听':0}))
data3Att=data3Att.append(Series({'根本没听':0}))
data5Att=data5Att.append(Series({'认真专注':0}))

# %%
plt.rcParams['font.sans-serif'] = ['simhei']
plt.rcParams['axes.unicode_minus'] = False
bar_width=0.15
labels2 = list(data1Att.index)
plt.ylabel('数量(人)')
x=np.arange(len(labels2))
plt.bar(x-2*bar_width,data1Att,bar_width,color='red',label='计科大数据')
plt.bar(x-bar_width,data2Att,bar_width,color='orange',label='计科网络')
plt.bar(x,data3Att,bar_width,color='#E47833',label='软工')
plt.bar(x+bar_width,data4Att,bar_width,color='brown',label='数媒')
plt.bar(x+2*bar_width,data5Att,bar_width,color='#D89370',label='金融实验')
plt.xticks(x,labels2)
plt.title('不同专业的听课专注力',size=18)
plt.yticks(range(0,40,5))
plt.legend()
plt.show()

# %%
labels2 = list(dataAtt.index)
x=np.arange(len(labels2))
bar_width=0.5
plt.bar(x,dataAtt,bar_width)
plt.title('学生听课专注力',size=18)
plt.xticks(x,labels2)
plt.yticks(range(0,65,5))
plt.show()

# %% [markdown]
# ## 课堂知识吸收度

# %%
data1Abs=data1['课堂知识的吸收度'].value_counts(ascending=False)
data2Abs=data2['课堂知识的吸收度'].value_counts(ascending=False)
data3Abs=data3['课堂知识的吸收度'].value_counts(ascending=False)
data4Abs=data4['课堂知识的吸收度'].value_counts(ascending=False)
data5Abs=data5['课堂知识的吸收度'].value_counts(ascending=False)
dataAbs=data['课堂知识的吸收度'].value_counts(ascending=False)
data2Abs=data2Abs.append(Series({'0-25%':0}))
data4Abs=data4Abs.append(Series({'0-25%':0,'51%-75%':0}))
data5Abs=data5Abs.append(Series({'26%-50%':0,'76%-100%':0}))

# %%
labels3 = list(data1Abs.index)
x=np.arange(len(labels3))
bar_width=0.15
plt.bar(x-2*bar_width,data1Abs,bar_width,color='red',label='计科大数据')
plt.bar(x-bar_width,data2Abs,bar_width,color='orange',label='计科网络')
plt.bar(x,data3Abs,bar_width,color='#E47833',label='软工')
plt.bar(x+bar_width,data4Abs,bar_width,color='brown',label='数媒')
plt.bar(x+2*bar_width,data5Abs,bar_width,color='#D89370',label='金融实验')
plt.xticks(x,labels3)
plt.title('不同专业的课堂知识的吸收度',size=18)
plt.yticks(range(0,25,5))
plt.legend()
plt.show()

# %%
plt.figure(figsize=(4,4))
absolute=['很低','低','一般','高']
share =[dataAbs['0-25%']/count,dataAbs['26%-50%']/count,dataAbs['51%-75%']/count,dataAbs['76%-100%']/count]
explode = [0.04, 0.04,0.04,0.04]
plt.pie(share, explode = explode,
        labels = absolute, autopct = '%3.2f%%',
        startangle = 0, shadow = False,
        colors = ['lightgreen', 'lightskyblue','#32CD32','#38B0DE'])
plt.title('课堂知识吸收度',size=18)
plt.axis('equal')
plt.show()

# %% [markdown]
# ## 笔记情况

# %%
dataWrite1=data['线下听课做笔记情况'].value_counts(ascending=False)
dataWrite2=data['线上听课做笔记情况'].value_counts(ascending=False)

# %%
plt.figure(figsize=(8,4))
write=['一直做笔记','适当做笔记','完全不做']
share =[dataWrite1['一直做笔记']/count,dataWrite1['适当做笔记']/count,dataWrite1['完全不做']/count]
share2=[dataWrite2['一直做笔记']/count,dataWrite2['适当做笔记']/count,dataWrite2['完全不做']/count]
explode = [0.04, 0.04,0.04]

plt.subplot(121)
plt.pie(share, explode = explode,
        labels = write, autopct = '%3.2f%%',
        startangle = 45, shadow = False,
        colors = ['lightgreen', 'lightskyblue','#32CD32'])
plt.title('线下听课做笔记情况',size=18)
plt.axis('equal')

plt.subplot(122)
plt.pie(share2, explode = explode,
        labels = write, autopct = '%3.2f%%',
        startangle = -60, shadow = False,
        colors = ['lightgreen', 'lightskyblue','#32CD32'])
plt.title('线上听课做笔记情况',size=18)
plt.axis('equal')
plt.show()

# %% [markdown]
# ## 听课时会不会做其他课外事情

# %%
dataDo=data['28、你在听课时会不会做其他课外事情？'].value_counts(ascending=False)

# %%
plt.figure(figsize=(4,4))
labels4=list(dataDo.index)
count=69
share =[dataDo[0]/count,dataDo[1]/count]
explode = [0.04, 0.04]
plt.pie(share, explode = explode,
        labels = labels4, autopct = '%3.2f%%',
        startangle = 60, shadow = False,
        colors = ['lightgreen', 'lightskyblue'])
plt.title('听课时做其他课外事情',size=18)
plt.axis('equal')
plt.show()

# %% [markdown]
# ## 作业完成度

# %%
dataFin=(data['作业完成度'].value_counts(ascending=False))

# %%
labels5 = list(dataFin.index)
x=np.arange(len(labels5))
bar_width=0.5
plt.bar(x,dataFin,bar_width)
plt.title('作业完成度',size=18)
plt.xticks(x,labels5)
plt.yticks(range(0,45,5))
plt.show()

# %% [markdown]
# ## 满意度

# %%
dataSatis=(data['网课满意度'].value_counts(ascending=False))
dataSatis=[dataSatis['很不满意'],dataSatis['不满意'],dataSatis['一般'],dataSatis['满意'],dataSatis['很满意']]

# %%
labels5 = ['很不满意','不满意','一般','满意','很满意']
x=np.arange(len(labels5))
bar_width=0.5
plt.bar(x,dataSatis,bar_width)
plt.title('网课满意度',size=18)
plt.xticks(x,labels5)
plt.yticks(range(0,45,5))
plt.show()

# %% [markdown]
# ## 效率

# %%
dataEff=(data['效率'].value_counts(ascending=False))

# %%
labels7=list(dataEff.index)
x=np.arange(len(labels7))
bar_width=0.5
plt.bar(x,dataEff,bar_width)
plt.title('线下线下认为效率更高',size=18)
plt.xticks(x,labels7)
plt.yticks(range(0,60,5))
plt.show()

# %% [markdown]
# 绝大多数同学更认同传统授课，认为其对于学生的听课效率更高

# %% [markdown]
# ## 线上授课优点

# %%
def c2(data):
    y = [x for x in data['线上授课优点'].str.split('┋')]
    a1 = 0
    a2 = 0
    a3 = 0
    a4 = 0
    a5 = 0
    for item in y:
        for select in item:
            if select[0]=='时':
                a1+=1
            elif select[0]=='不':
                a2+=1
            elif select[0]=='支':
                a3+=1
            elif select[0]=='师':
                a4+=1
            else:
                a5+=1
    a=[]
    a.extend([a1,a2,a3,a4,a5])
    return a

# %%
plt.figure(figsize=(8,5)) 
labels8 = ['时间分配自由','不受老师管理，想干什么干什么','支持录屏，可以重复观看','师生互动不会显得环境吵杂','其他']
share =[(c2(data))[0]/count,(c2(data))[1]/count,(c2(data))[2]/count,(c2(data))[3]/count,(c2(data))[4]/count]
x=np.arange(len(labels8))
bar_width=0.5
plt.barh(x,share,bar_width)
plt.title('线上授课优点',size=18)
for a,b in zip(x,share): plt.text(b+0.03,a-0.05,"%.1f%%"%(b*100),ha='center', va= 'bottom',fontsize=12)
plt.yticks(x,labels8)
plt.show()

# %% [markdown]
# ## 线上授课缺点

# %%
def c3(data):
    y = [x for x in data['线上授课缺点'].str.split('┋')]
    a1 = 0
    a2 = 0
    a3 = 0
    a4 = 0
    a5 = 0
    for item in y:
        for select in item:
            if select[0]=='平':
                a1+=1
            elif select[0]=='注':
                a2+=1
            elif select[0]=='知':
                a3+=1
            elif select[0]=='周':
                a4+=1
            else:
                a5+=1
    a=[]
    a.extend([a1,a2,a3,a4,a5])
    return a

# %%
plt.figure(figsize=(8,5)) 
labels9=['平台声音杂、卡顿','注意力难以集中','知识难以吸收','周边环境影响大','其他']
share =[(c3(data))[0]/count,(c3(data))[1]/count,(c3(data))[2]/count,(c3(data))[3]/count,(c3(data))[4]/count]
x=np.arange(len(labels9))
bar_width=0.5
plt.barh(x,share,bar_width)
plt.title('线上授课缺点',size=18)
for a,b in zip(x,share): plt.text(b+0.04,a-0.05,"%.1f%%"%(b*100),ha='center', va= 'bottom',fontsize=12)
plt.yticks(x,labels9)
plt.show()

# %% [markdown]
# ## 老师直播方式

# %%
liveType = pd.read_excel('直播方式.xlsx')
liveType
# Out:
#        哔哩哔哩（B站）  蓝墨云班课  腾讯会议  QQ群直播  QQ群在线授课  网易云班课  至诚大数据慕课实验平台  斗鱼直播  其他
# 计科大数据        89    104    85     42       18     10           50     0   4
# 计科网络          0      0    32      3        1      0            5     0   0
# 软工            1      0    15      0        0      0            0     3   3
# 数媒            1      2     0      4        3      3            0     0   1
# 金融实验班         3      5     4      4        6      0            2     1   4
# 总和           94    111   136     53       28     13           57     4  12

# %%
total=(liveType.T)['总和'].sum()

# %%
plt.figure(figsize=(4,4))
labels10=list(liveType.T.index)
share =[(liveType.T)['总和'][0]/total,(liveType.T)['总和'][1]/total,(liveType.T)['总和'][2]/total,(liveType.T)['总和'][3]/total,(liveType.T)['总和'][4]/total,(liveType.T)['总和'][5]/total,(liveType.T)['总和'][6]/total,(liveType.T)['总和'][7]/total,(liveType.T)['总和'][8]/total]
#explode = [0.04, 0.04, 0.04, 0.04, 0.04, 0.04, 0.04, 0.04, 0.04]
plt.pie(share,labels = labels10, autopct = '%3.2f%%',
        startangle = 0, shadow = False,
        colors = ['lightgreen', 'lightskyblue','#32CD32','#38B0DE','#CC3299','#DB70DB','#9370DB','#3232CD','#70DB93'])
plt.title('老师直播方式比例',size=18)
plt.axis('equal')
plt.show()

# %%
plt.figure(figsize=(8,5)) 
labels10 = list(liveType.T.index)
share =[(liveType.T)['总和'][0]/total,(liveType.T)['总和'][1]/total,(liveType.T)['总和'][2]/total,(liveType.T)['总和'][3]/total,
        (liveType.T)['总和'][4]/total,(liveType.T)['总和'][5]/total,(liveType.T)['总和'][6]/total,(liveType.T)['总和'][7]/total,
        (liveType.T)['总和'][8]/total]
x=np.arange(len(labels10))
bar_width=0.5
plt.barh(x,share,bar_width)
plt.title('老师直播方式比例',size=18)
for a,b in zip(x,share): plt.text(b+0.015,a-0.1,"%.2f%%"%(b*100),ha='center', va= 'bottom',fontsize=12)
plt.yticks(x,labels10)
plt.show()

# %%
sns.countplot(x="性别",data=data)

# %%
plt.figure(figsize=(10,5))
plt.xticks(rotation=15)
sns.countplot(x="专业",data=data)
